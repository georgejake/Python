# %%
#Area of football field
length = 92
width = 48.8
area = print(round(length * width,3))
# Out:
# 4489.6

# %%
#Potato chips balance
costof1pack = 1.49
totalpackets = 9
balance = 20 -(1.49*9)
print(balance)
# Out:
# 6.59

# %%
#Tile relaying
areaofbathroominsqft = 5.5**2
costpersqft = 500
totalcost = print(areaofbathroominsqft * 500)
# Out:
# 15125.0

# %%
#Binary of number
num=17
binnum = format(num,'b')
print(f"i am {binnum}")
# Out:
# i am 10001

# %%
#use of fromat (self exploring
txt1 = "My name is {fname}, I'm {age}".format(fname = "John", age = 36)
txt2 = "My name is {0}, I'm {1}".format("John",36)
txt3 = "My name is {}, I'm {}".format("John",36)

txt4 = "Binary of number 17 is {bin17:b}"
print(txt4.format(bin17=17))
# Out:
# Binary of number 17 is 10001
