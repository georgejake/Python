# %%
import datetime
birthyear = 1981
today = datetime.date.today()
currentyear = today.year
print(type(today.year))
age = currentyear - birthyear
print(age)

fname="George"
lname="Jacob"
print("George","Jacob")

# Invalid variable naming convention 1record, record-one, record^one
# Out:
# <class 'int'>
# 44
# George Jacob
