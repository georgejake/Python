# %%
'''
Python Method creates an immutable Set object from an iterable. It is a built-in Python function.
As it is a set object, therefore, we cannot have duplicate values in the frozenset.
Syntax : frozenset(iterable_object_name)
'''
mylist = [1,2,3,4]
myset = set(mylist)
myfrozenset = frozenset(mylist)
print(myfrozenset)
#Cannot add elements to frozen set ,in many ways i think it is similar to tuple in terms of being immutable
#myfrozenset.add(10)
myset.add(10)
print(myset)
# Out:
# frozenset({1, 2, 3, 4})
# {1, 2, 3, 4, 10}

# %%
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}
#Difference using - operator
print(set1-set2)
#Difference using difference operator
print(set1.difference(set2))
# Out:
# {1, 2, 3}
# {1, 2, 3}
